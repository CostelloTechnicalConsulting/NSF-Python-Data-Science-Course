# %% [markdown]
# # Exercise 1-1: Get started with JupyterLab

# %% [markdown]
# ## Get the data

# %%
import pandas as pd
awd_url = 'https://onlcfiles.blob.core.windows.net/clientfiles/NSF/nsf-awards-2010-2025.csv'
awards = pd.read_csv(awd_url)
# Out:
# C:\Users\dan\AppData\Local\Temp\ipykernel_3868\1830717588.py:3: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   awards = pd.read_csv(awd_url)

# %%
awards
# Out:
#          awd_id agcy_id   tran_type           awd_istr_txt  \
# 0        415302     NSF  CoopAgrmnt  Cooperative Agreement
# 1        731599     NSF       Grant         Standard Grant
# 2        804541     NSF       Grant         Standard Grant
# 3        805878     NSF       Grant         Standard Grant
# 4        805989     NSF       Grant         Standard Grant
# ...         ...     ...         ...                    ...
# 187577  2530272     NSF       Grant         Standard Grant
# 187578  2530288     NSF       Grant         Standard Grant
# 187579  2530438     NSF       Grant         Standard Grant
# 187580  2531173     NSF       Grant       Continuing Grant
# 187581  2531174     NSF       Grant       Continuing Grant
#
#                                              awd_titl_txt cfda_num  org_code  \
# 0       Advanced Technology Solar Telescope (ATST) Con...   47.049   3020000
# 1       Individual - Nomination for Presidential Award...   47.076  11040300
# 2       The Geometric Background of biHamiltonian Systems   47.049   3040000
# 3       The Semiclassical Limit and Geometric Quantiza...   47.049   3040000
# 4       Application of methods of arithmetic geometry ...   47.049   3040000
# ...                                                   ...      ...       ...
# 187577  Collaborative Research: RAPID: A multi-scale a...   47.050   6040000
# 187578  EF: Collaborative Research: MTM 2: Marine Inve...   47.074   8040000
# 187579              Ricci Flows and Steady Ricci Solitons   47.049   3040000
# 187580  RCN: Instrumentation for Quantum Biology (I-Qu...   47.074   8070000
# 187581  CAREER:Strategic behavior, beliefs, and interv...   47.075   4050000
#
#             po_phone          po_email         po_sign_block_name  ...  \
# 0                NaN               NaN              David Boboltz  ...
# 1       7.032928e+09    mjames@nsf.gov               Martha James  ...
# 2                NaN               NaN          Christopher Stark  ...
# 3                NaN               NaN          Christopher Stark  ...
# 4                NaN               NaN          Christopher Stark  ...
# ...              ...               ...                        ...  ...
# 187577  7.032925e+09  jgardine@nsf.gov             Jayne Gardiner  ...
# 187578  7.032925e+09   dkabbot@nsf.gov              Patrick Abbot  ...
# 187579  7.032925e+09  jkaniaba@nsf.gov  Joanna Kania-Bartoszynska  ...
# 187580  7.032928e+09  wfrancis@nsf.gov           Wilson Francisco  ...
# 187581  7.032927e+09     nlutz@nsf.gov                 Nancy Lutz  ...
#
#               perf_inst.perf_str_addr perf_inst.perf_city_name  \
# 0                    950 N CHERRY AVE                   TUCSON
# 1               1111 FRANKLIN ST FL 8                  OAKLAND
# 2               21 N PARK ST STE 6301                  MADISON
# 3            1109 GEDDES AVE STE 3300                ANN ARBOR
# 4       1850 RESEARCH PARK DR STE 300                    DAVIS
# ...                               ...                      ...
# 187577            1608 4TH ST STE 201                 BERKELEY
# 187578              5800 BAY SHORE RD                 SARASOTA
# 187579               160 ALDRICH HALL                   IRVINE
# 187580            1903 W MICHIGAN AVE                KALAMAZOO
# 187581                   633 CLARK ST                 EVANSTON
#
#         perf_inst.perf_st_code  perf_inst.perf_st_name  \
# 0                           AZ                 Arizona
# 1                           CA              California
# 2                           WI               Wisconsin
# 3                           MI                Michigan
# 4                           CA              California
# ...                        ...                     ...
# 187577                      CA              California
# 187578                      FL                 Florida
# 187579                      CA              California
# 187580                      MI                Michigan
# 187581                      IL                Illinois
#
#        perf_inst.perf_zip_code perf_inst.perf_ctry_code  \
# 0                    857194933                       US
# 1                    946075201                       US
# 2                    537151218                       US
# 3                    481091015                       US
# 4                    956186153                       US
# ...                        ...                      ...
# 187577               947101749                       US
# 187578               342432101                       US
# 187579               926970001                       US
# 187580               490085200                       US
# 187581               602080001                       US
#
#         perf_inst.perf_cong_dist perf_inst.perf_st_cong_dist  \
# 0                            7.0                        AZ07
# 1                           12.0                        CA12
# 2                            2.0                        WI02
# 3                            6.0                        MI06
# 4                            4.0                        CA04
# ...                          ...                         ...
# 187577                      12.0                        CA12
# 187578                      17.0                        FL17
# 187579                      47.0                        CA47
# 187580                       4.0                        MI04
# 187581                       9.0                        IL09
#
#        perf_inst.perf_ctry_name perf_inst.perf_ctry_flag
# 0                           NaN                        1
# 1                           NaN                        1
# 2                           NaN                        1
# 3                           NaN                        1
# 4                           NaN                        1
# ...                         ...                      ...
# 187577            United States                        1
# 187578            United States                        1
# 187579            United States                        1
# 187580            United States                        1
# 187581            United States                        1
#
# [187582 rows x 48 columns]

# %%
awards.sort_values('awd_titl_txt',inplace=True)
awards.head(10)
# Out:
#          awd_id agcy_id   tran_type           awd_istr_txt  \
# 2326     956545     NSF  CoopAgrmnt  Cooperative Agreement
# 98388   1742961     NSF       Grant         Standard Grant
# 11466   1035417     NSF       Grant         Standard Grant
# 8091    1016314     NSF       Grant         Standard Grant
# 48280   1340387     NSF       Grant         Standard Grant
# 72815   1542531     NSF       Grant         Standard Grant
# 46484   1329300     NSF       Grant         Standard Grant
# 45359   1319312     NSF       Grant         Standard Grant
# 119363  1916490     NSF       Grant         Standard Grant
# 11026   1032428     NSF       Grant         Standard Grant
#
#                                              awd_titl_txt cfda_num  org_code  \
# 2326    \tManagement and Operations of the Green Bank ...   47.049   3020000
# 98388   "13th International Conference on Catalysis in...   47.041   7020000
# 11466   "2010"- Mississippi State University Biofuels ...   47.041   7020000
# 8091    "A Joint US-European Workshop on Informatics f...   47.079   1090000
# 48280   "A Joint US-European Workshop on Informatics f...   47.079   1090000
# 72815   "A Long Way Coming"--Understanding Engineering...   47.041   7050000
# 46484   "A Long Way Coming"--Understanding Engineering...   47.041   7050000
# 45359   "AF:Small:Efficient and reliable low-rank appr...   47.070   5010000
# 119363  "Advancing Students' Proof Practices in Mathem...   47.076  11040000
# 11026   "An International Symposium on Solvation and I...   47.041   7020000
#
#             po_phone          po_email         po_sign_block_name  ...  \
# 2326    7.032925e+09    hgupta@nsf.gov              Harshal Gupta  ...
# 98388            NaN               NaN  Triantafillos Mountziaris  ...
# 11466            NaN               NaN             Bruce Hamilton  ...
# 8091             NaN               NaN                  Anne Emig  ...
# 48280            NaN               NaN                  Anne Emig  ...
# 72815            NaN               NaN             Elliot Douglas  ...
# 46484            NaN               NaN                Donna Riley  ...
# 45359            NaN               NaN              Tracy Kimbrel  ...
# 119363  7.032923e+09  mferrara@nsf.gov               Mike Ferrara  ...
# 11026   7.032922e+09  asimonia@nsf.gov         Aleksandr Simonian  ...
#
#               perf_inst.perf_str_addr perf_inst.perf_city_name  \
# 2326       2650 PARK TOWER DR STE 700                   VIENNA
# 98388                             NaN                      NaN
# 11466                    245 BARR AVE        MISSISSIPPI STATE
# 8091    2199 S UNIVERSITY BLVD RM 222                   DENVER
# 48280              Northern Boulevard             Old Westbury
# 72815                             NaN                      NaN
# 46484           200 D.W. Brooks Drive                   Athens
# 45359                             NaN                 Berkeley
# 119363                            NaN                 Portland
# 11026         104 AIRPORT DR STE 2200              CHAPEL HILL
#
#         perf_inst.perf_st_code  perf_inst.perf_st_name  \
# 2326                        VA                Virginia
# 98388                       TX                   Texas
# 11466                       MS             Mississippi
# 8091                        CO                Colorado
# 48280                       NY                New York
# 72815                       AZ                 Arizona
# 46484                       GA                 Georgia
# 45359                       CA              California
# 119363                      OR                  Oregon
# 11026                       NC          North Carolina
#
#        perf_inst.perf_zip_code perf_inst.perf_ctry_code  \
# 2326                 221807300                       US
# 98388                778433122                       US
# 11466                    39762                       US
# 8091                 802104711                       US
# 48280                115688000                       US
# 72815                852816011                       US
# 46484                306025016                       US
# 45359                947203840                       US
# 119363               972070751                       US
# 11026                275995023                       US
#
#         perf_inst.perf_cong_dist perf_inst.perf_st_cong_dist  \
# 2326                        11.0                        VA11
# 98388                       10.0                        TX10
# 11466                        3.0                        MS03
# 8091                         1.0                        CO01
# 48280                        3.0                        NY03
# 72815                        4.0                        AZ04
# 46484                       10.0                        GA10
# 45359                       12.0                        CA12
# 119363                       1.0                        OR01
# 11026                        4.0                        NC04
#
#        perf_inst.perf_ctry_name perf_inst.perf_ctry_flag
# 2326                        NaN                        1
# 98388             United States                        1
# 11466                       NaN                        1
# 8091                        NaN                        1
# 48280             United States                        1
# 72815             United States                        1
# 46484             United States                        1
# 45359             United States                        1
# 119363            United States                        1
# 11026                       NaN                        1
#
# [10 rows x 48 columns]

# %% [markdown]
# ## Use tab completion and tooltips

# %%
awards.sort_values('awd_titl_txt', ascending=False).head()
# Out:
#          awd_id agcy_id tran_type    awd_istr_txt  \
# 156606  2209698     NSF     Grant  Standard Grant
# 158664  2218973     NSF     Grant  Standard Grant
# 148500  2131802     NSF     Grant  Standard Grant
# 182531  2421240     NSF     Grant  Standard Grant
# 182532  2421241     NSF     Grant  Standard Grant
#
#                                              awd_titl_txt cfda_num  org_code  \
# 156606  “Sustainable Polymers: Physics of New Material...   47.049   3070000
# 158664  “Puerto Rican Higher Education Researchers Ass...   47.076  11060000
# 148500  “Autonomous Flying Fire Blanket”: New Adaptive...   47.041   7010000
# 182531  ¿Quiénes son? Assessing Language Skills, Belon...   47.076  11060000
# 182532  ¿Quiénes son? Assessing Language Skills, Belon...   47.076  11060000
#
#             po_phone          po_email   po_sign_block_name  ...  \
# 156606  7.032925e+09  alovinge@nsf.gov      Andrew Lovinger  ...
# 158664  7.032920e+09  smontash@nsf.gov  Sonja Montas-Hunter  ...
# 148500  7.032922e+09     eabed@nsf.gov            Eyad Abed  ...
# 182531  7.032920e+09  smontash@nsf.gov  Sonja Montas-Hunter  ...
# 182532  7.032920e+09  smontash@nsf.gov  Sonja Montas-Hunter  ...
#
#            perf_inst.perf_str_addr perf_inst.perf_city_name  \
# 156606           4726 Calhoun Road                  Houston
# 158664                         NaN                      NaN
# 148500         500 South Limestone                Lexington
# 182531               524 W 59TH ST                 NEW YORK
# 182532  500 GRAND CONCOURSE #B-319                    BRONX
#
#         perf_inst.perf_st_code  perf_inst.perf_st_name  \
# 156606                      TX                   Texas
# 158664                      DC    District of Columbia
# 148500                      KY                Kentucky
# 182531                      NY                New York
# 182532                      NY                New York
#
#        perf_inst.perf_zip_code perf_inst.perf_ctry_code  \
# 156606               772044004                       US
# 158664               200091692                       US
# 148500               405260001                       US
# 182531               100191007                       US
# 182532               104515323                       US
#
#         perf_inst.perf_cong_dist perf_inst.perf_st_cong_dist  \
# 156606                      18.0                        TX18
# 158664                       0.0                        DC00
# 148500                       6.0                        KY06
# 182531                      12.0                        NY12
# 182532                      15.0                        NY15
#
#        perf_inst.perf_ctry_name perf_inst.perf_ctry_flag
# 156606            United States                        1
# 158664            United States                        1
# 148500            United States                        1
# 182531            United States                        1
# 182532            United States                        1
#
# [5 rows x 48 columns]
